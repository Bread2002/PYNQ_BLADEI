# %% [markdown]
# # **Machine Learning-Based Detection of Simulated Malware in FPGA Bitstreams**
# ### *Copyright (c) 2025, Rye Stahle-Smith*
# ---
# #### ***Description:***
# This project explores the application of machine learning techniques to detect malicious modifications in FPGA bitstreams, specifically targeting the *PYNQ-Z1 FPGA Development Board* by Xilinx and Digilent. Rather than relying on custom-generated data, the project now leverages state-of-the-art (SOTA) benchmarks from **Trust-Hub**, a resource sponsored by the **National Science Foundation (NSF)**. Although these benchmarks have not been updated since 2013, they represent realistic chip-level attack scenarios. The original designs were re-engineered and adapted to work with the PYNQ-Z1 platform. As of the latest update, the dataset consists of ***one-hundred and twenty-two samples*** — ***twenty-five benign AES-128, twenty-one benign RS232, twenty-five benign AES-128, twenty-one benign RS232, and thirty empty bitstreams***.
#
# #### ***Objectives:***
# **Objective 1: Integrate and adapt industry-standard benchmarks for modern FPGA platforms.** <br>
# Task 1.1: Reconfigure Trust-Hub HDL benchmarks to compile and synthesize successfully using Xilinx Vivado for compatibility with PYNQ-Z1. <br>
# Task 1.2: Synthesize and implement modules on the PYNQ-Z1 board to verify functional correctness and hardware compatibility. <br>
# Task 1.3: Organize, label, and curate the bitstream dataset across multiple classes (benign, malicious, empty) for use in supervised learning. <br>
#
# **Objective 2: Design an ML-based detection pipeline for hardware Trojans in FPGA bitstreams.** <br>
# Task 2.1: Convert raw .bit files into sparse byte-frequency representations and apply dimensionality reduction using Truncated Singular Value Decomposition (TSVD). <br>
# Task 2.2: Apply SMOTE (Synthetic Minority Oversampling Technique) to balance class distributions in the training set and mitigate bias. <br>
# Task 2.3: Train and compare multiple classifiers (Random Forest, Decision Tree, SVM, Gradient Boosting, etc.) using k-fold cross-validation to identify the most effective model. <br>
#
# **Objective 3: Evaluate model performance and ensure robustness across Trojan variants.** <br>
# Task 3.1: Analyze performance using metrics such as accuracy, precision, recall, F1-score, and class-wise true/false positive rates. <br>
# Task 3.2: Generate confusion matrices and perform error analysis to assess model weaknesses and edge cases. <br>
# Task 3.3: Assess model robustness by deploying the trained model on the PYNQ-Z1 platform to validate real-time prediction performance and resource efficiency in a target embedded environment. <br>
#
# #### ***Sources:***
# Hayashi, V. T., & Vicente Ruggiero, W. (2025). Hardware Trojan Detection in Open-Source Hardware Designs Using Machine Learning. *IEEE Access*. https://ieeexplore.ieee.org/document/10904479 <br>
# Elnaggar, R., Chaudhuri, J., Karri, R., & Chakrabarty, K. (2023). Learning Malicious Circuits in FPGA Bitstreams. *IEEE Transactions on Computer-Aided Design of Integrated Circuits and Systems*, 42(3), 726–739. https://ieeexplore.ieee.org/document/9828544<br>
# Pedregosa, F., et al. (2011). scikit-learn: Machine Learning in Python. *Journal of Machine Learning Research*, 12, 2825–2830. https://dl.acm.org/doi/10.5555/1953048.2078195<br>

# %%
# --------------------------
# Step 1: Deploy Trained Model on PYNQ-Z1
# This step loads the serialized ML model and uses it to make predictions on the PYNQ-Z1 board.
# --------------------------
from rf_predictor import predict_bitstream
from collections import Counter
import numpy as np
import random
import platform
import psutil
import os
import time

base_path = "trusthub_bitstreams"
categories = ["Empty", "Benign", "Malicious"]
total_time_ms = 0
num_trials = 100
num_failed = 0

bitstream_files = []
for category in categories:
    folder_path = os.path.join(base_path, category)
    for file in os.listdir(folder_path):
        if file.endswith(".bit"):
            bitstream_files.append(os.path.join(folder_path, file))

label_map = {
    0: "Empty (Class 0)",
    1: "Benign (Class 1)",
    2: "Malicious (Class 2)",
}

for trial in range(num_trials):
    bitstream_path = random.choice(bitstream_files)
    filename = os.path.basename(bitstream_path)
    folder = os.path.basename(os.path.dirname(bitstream_path))

    print(f"*** Trial {trial + 1}: Processing {filename}... ***")

    if folder == "Empty":
        actual_class = "Empty (Class 0)"
    elif folder == "Benign":
        actual_class = "Benign (Class 1)"
    elif folder == "Malicious":
        actual_class = "Malicious (Class 2)"
    else:
        actual_class = "Unknown"

    # Measure Load Time
    start_load = time.time()
    with open(bitstream_path, 'rb') as f:
        data = f.read()
    end_load = time.time()

    # Measure Feature Extraction Time
    start_feat = time.time()
    size = len(data)
    if size == 0:
        features = np.zeros(256)
    else:
        counts = Counter(data)
        dense_vec = np.zeros(256)
        for byte_val, count in counts.items():
            dense_vec[byte_val] = count / size
        features = dense_vec
    end_feat = time.time()

    # Measure Prediction Time
    start_pred = time.time()
    prediction = predict_bitstream(features)
    end_pred = time.time()

    predicted_class = label_map.get(prediction, "Unknown")
    
    print(f"Actual Class:    {actual_class}")
    print(f"Predicted Class: {predicted_class}")

    num_failed += 1 if (actual_class != predicted_class) else 0

    load_time_ms = (end_load - start_load) * 1000
    feat_time_ms = (end_feat - start_feat) * 1000
    pred_time_ms = (end_pred - start_pred) * 1000

    print(f"\n=== Latency Summary ===")
    print(f"Load Bitstream:      {load_time_ms:.2f} ms")
    print(f"Feature Extraction:  {feat_time_ms:.2f} ms")
    print(f"Prediction:          {pred_time_ms:.2f} ms\n")
    
    total_time_ms += load_time_ms + feat_time_ms + pred_time_ms
    
print(f"\nAverage Latency: {total_time_ms / num_trials / 1000:.2f} s")
print(f"\nTrials Failed: {num_failed} trials")
# Out:
# *** Trial 1: Processing AES_T1000_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.53 ms
# Feature Extraction:  167.65 ms
# Prediction:          0.76 ms
#
# *** Trial 2: Processing RS232_T700.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      2.72 ms
# Feature Extraction:  158.42 ms
# Prediction:          0.91 ms
#
# *** Trial 3: Processing RS232_T1800_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      12.49 ms
# Feature Extraction:  160.16 ms
# Prediction:          0.34 ms
#
# *** Trial 4: Processing empty6.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      2.86 ms
# Feature Extraction:  166.72 ms
# Prediction:          0.77 ms
#
# *** Trial 5: Processing AES_T500.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      2.70 ms
# Feature Extraction:  167.05 ms
# Prediction:          0.39 ms
#
# *** Trial 6: Processing AES_T300.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      2.50 ms
# Feature Extraction:  161.69 ms
# Prediction:          0.89 ms
#
# *** Trial 7: Processing AES_T2300_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.83 ms
# Feature Extraction:  178.48 ms
# Prediction:          0.34 ms
#
# *** Trial 8: Processing AES_T2300.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      2.84 ms
# Feature Extraction:  166.87 ms
# Prediction:          0.84 ms
#
# *** Trial 9: Processing RS232_T600_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      4.16 ms
# Feature Extraction:  166.95 ms
# Prediction:          0.32 ms
#
# *** Trial 10: Processing RS232_T900.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      2.72 ms
# Feature Extraction:  161.03 ms
# Prediction:          0.73 ms
#
# *** Trial 11: Processing empty5.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      11.98 ms
# Feature Extraction:  160.88 ms
# Prediction:          0.32 ms
#
# *** Trial 12: Processing AES_T2100.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      2.91 ms
# Feature Extraction:  165.89 ms
# Prediction:          0.86 ms
#
# *** Trial 13: Processing AES_T1600.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      2.61 ms
# Feature Extraction:  164.98 ms
# Prediction:          0.81 ms
#
# *** Trial 14: Processing RS232_T1800_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      1.60 ms
# Feature Extraction:  167.28 ms
# Prediction:          1.54 ms
#
# *** Trial 15: Processing AES_T1800.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      1.89 ms
# Feature Extraction:  176.96 ms
# Prediction:          0.36 ms
#
# *** Trial 16: Processing RS232_T1800.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      2.39 ms
# Feature Extraction:  178.07 ms
# Prediction:          0.95 ms
#
# *** Trial 17: Processing RS232_T400_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.65 ms
# Feature Extraction:  163.67 ms
# Prediction:          0.77 ms
#
# *** Trial 18: Processing RS232_T1800_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      0.99 ms
# Feature Extraction:  168.02 ms
# Prediction:          0.91 ms
#
# *** Trial 19: Processing AES_T700_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.94 ms
# Feature Extraction:  166.87 ms
# Prediction:          1.26 ms
#
# *** Trial 20: Processing RS232_T900.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      0.77 ms
# Feature Extraction:  161.63 ms
# Prediction:          0.71 ms
#
# *** Trial 21: Processing empty4.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      2.66 ms
# Feature Extraction:  175.18 ms
# Prediction:          0.42 ms
#
# *** Trial 22: Processing AES_T600_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.85 ms
# Feature Extraction:  161.65 ms
# Prediction:          0.86 ms
#
# *** Trial 23: Processing AES_T300.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      1.07 ms
# Feature Extraction:  170.46 ms
# Prediction:          0.82 ms
#
# *** Trial 24: Processing AES_T400_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.10 ms
# Feature Extraction:  169.72 ms
# Prediction:          0.34 ms
#
# *** Trial 25: Processing RS232_T1800_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      1.02 ms
# Feature Extraction:  185.95 ms
# Prediction:          0.61 ms
#
# *** Trial 26: Processing empty30.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      2.56 ms
# Feature Extraction:  163.24 ms
# Prediction:          0.32 ms
#
# *** Trial 27: Processing RS232_T1400_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.04 ms
# Feature Extraction:  163.28 ms
# Prediction:          1.48 ms
#
# *** Trial 28: Processing empty2.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      2.59 ms
# Feature Extraction:  161.15 ms
# Prediction:          0.33 ms
#
# *** Trial 29: Processing empty9.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      2.54 ms
# Feature Extraction:  158.38 ms
# Prediction:          5.58 ms
#
# *** Trial 30: Processing empty13.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      2.55 ms
# Feature Extraction:  156.62 ms
# Prediction:          0.33 ms
#
# *** Trial 31: Processing RS232_T300_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      3.08 ms
# Feature Extraction:  175.72 ms
# Prediction:          0.91 ms
#
# *** Trial 32: Processing RS232_T1800_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      1.17 ms
# Feature Extraction:  217.09 ms
# Prediction:          0.95 ms
#
# *** Trial 33: Processing AES_T400_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      1.57 ms
# Feature Extraction:  203.37 ms
# Prediction:          1.06 ms
#
# *** Trial 34: Processing AES_T200_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.08 ms
# Feature Extraction:  186.40 ms
# Prediction:          0.36 ms
#
# *** Trial 35: Processing empty29.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      1.75 ms
# Feature Extraction:  159.39 ms
# Prediction:          2.36 ms
#
# *** Trial 36: Processing empty15.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      4.52 ms
# Feature Extraction:  149.80 ms
# Prediction:          0.32 ms
#
# *** Trial 37: Processing RS232_T1100_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.39 ms
# Feature Extraction:  161.83 ms
# Prediction:          0.68 ms
#
# *** Trial 38: Processing AES_T300_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      1.86 ms
# Feature Extraction:  160.04 ms
# Prediction:          0.33 ms
#
# *** Trial 39: Processing AES_T2100.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      0.70 ms
# Feature Extraction:  176.32 ms
# Prediction:          1.13 ms
#
# *** Trial 40: Processing RS232_T700_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.56 ms
# Feature Extraction:  159.82 ms
# Prediction:          0.33 ms
#
# *** Trial 41: Processing AES_T700.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      2.81 ms
# Feature Extraction:  165.47 ms
# Prediction:          0.81 ms
#
# *** Trial 42: Processing AES_T800_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      4.68 ms
# Feature Extraction:  178.96 ms
# Prediction:          0.80 ms
#
# *** Trial 43: Processing AES_T2000_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.74 ms
# Feature Extraction:  165.48 ms
# Prediction:          0.97 ms
#
# *** Trial 44: Processing AES_T900_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      6.12 ms
# Feature Extraction:  172.95 ms
# Prediction:          0.40 ms
#
# *** Trial 45: Processing empty3.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      2.35 ms
# Feature Extraction:  158.78 ms
# Prediction:          0.66 ms
#
# *** Trial 46: Processing RS232_T500_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      4.61 ms
# Feature Extraction:  171.83 ms
# Prediction:          0.33 ms
#
# *** Trial 47: Processing RS232_T1600_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.65 ms
# Feature Extraction:  153.84 ms
# Prediction:          3.14 ms
#
# *** Trial 48: Processing AES_T800_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      4.71 ms
# Feature Extraction:  178.82 ms
# Prediction:          0.34 ms
#
# *** Trial 49: Processing RS232_T1300.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      2.32 ms
# Feature Extraction:  169.03 ms
# Prediction:          0.99 ms
#
# *** Trial 50: Processing AES_T1700.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      2.30 ms
# Feature Extraction:  178.10 ms
# Prediction:          0.77 ms
#
# *** Trial 51: Processing RS232_T500_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      1.11 ms
# Feature Extraction:  176.51 ms
# Prediction:          0.72 ms
#
# *** Trial 52: Processing RS232_T600_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      1.09 ms
# Feature Extraction:  158.21 ms
# Prediction:          1.05 ms
#
# *** Trial 53: Processing RS232_T1700_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.67 ms
# Feature Extraction:  176.81 ms
# Prediction:          0.33 ms
#
# *** Trial 54: Processing AES_T300_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      0.69 ms
# Feature Extraction:  170.98 ms
# Prediction:          0.80 ms
#
# *** Trial 55: Processing empty6.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      1.61 ms
# Feature Extraction:  168.45 ms
# Prediction:          0.78 ms
#
# *** Trial 56: Processing AES_T2400.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      2.79 ms
# Feature Extraction:  171.58 ms
# Prediction:          8.72 ms
#
# *** Trial 57: Processing AES_T1300_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      3.21 ms
# Feature Extraction:  168.99 ms
# Prediction:          0.35 ms
#
# *** Trial 58: Processing empty5.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      1.71 ms
# Feature Extraction:  161.43 ms
# Prediction:          0.78 ms
#
# *** Trial 59: Processing AES_T200.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      1.96 ms
# Feature Extraction:  164.95 ms
# Prediction:          0.36 ms
#
# *** Trial 60: Processing AES_T1700.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      0.71 ms
# Feature Extraction:  166.06 ms
# Prediction:          5.63 ms
#
# *** Trial 61: Processing empty17.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      3.70 ms
# Feature Extraction:  175.64 ms
# Prediction:          0.86 ms
#
# *** Trial 62: Processing empty8.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      2.62 ms
# Feature Extraction:  163.07 ms
# Prediction:          0.34 ms
#
# *** Trial 63: Processing empty27.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      2.39 ms
# Feature Extraction:  158.69 ms
# Prediction:          0.70 ms
#
# *** Trial 64: Processing empty3.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      1.03 ms
# Feature Extraction:  174.61 ms
# Prediction:          0.73 ms
#
# *** Trial 65: Processing empty10.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      7.92 ms
# Feature Extraction:  170.17 ms
# Prediction:          1.13 ms
#
# *** Trial 66: Processing empty12.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      2.41 ms
# Feature Extraction:  167.23 ms
# Prediction:          0.84 ms
#
# *** Trial 67: Processing AES_T1000_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.47 ms
# Feature Extraction:  178.18 ms
# Prediction:          0.33 ms
#
# *** Trial 68: Processing AES_T100.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.56 ms
# Feature Extraction:  160.68 ms
# Prediction:          0.70 ms
#
# *** Trial 69: Processing AES_T2100_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.41 ms
# Feature Extraction:  205.05 ms
# Prediction:          1.24 ms
#
# *** Trial 70: Processing RS232_T800_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.64 ms
# Feature Extraction:  169.94 ms
# Prediction:          0.33 ms
#
# *** Trial 71: Processing RS232_T901.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      2.73 ms
# Feature Extraction:  159.76 ms
# Prediction:          0.83 ms
#
# *** Trial 72: Processing RS232_T900_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.37 ms
# Feature Extraction:  170.49 ms
# Prediction:          0.79 ms
#
# *** Trial 73: Processing RS232_T2000_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.63 ms
# Feature Extraction:  162.21 ms
# Prediction:          0.84 ms
#
# *** Trial 74: Processing empty3.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      1.06 ms
# Feature Extraction:  162.31 ms
# Prediction:          0.85 ms
#
# *** Trial 75: Processing RS232_T1600.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      11.26 ms
# Feature Extraction:  171.43 ms
# Prediction:          0.80 ms
#
# *** Trial 76: Processing RS232_T1300.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      5.58 ms
# Feature Extraction:  176.99 ms
# Prediction:          3.73 ms
#
# *** Trial 77: Processing RS232_T1700.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      2.64 ms
# Feature Extraction:  173.39 ms
# Prediction:          0.35 ms
#
# *** Trial 78: Processing RS232_T1000.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      2.50 ms
# Feature Extraction:  153.88 ms
# Prediction:          1.19 ms
#
# *** Trial 79: Processing RS232_T2000.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      2.46 ms
# Feature Extraction:  164.84 ms
# Prediction:          0.34 ms
#
# *** Trial 80: Processing empty8.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      0.72 ms
# Feature Extraction:  180.71 ms
# Prediction:          0.79 ms
#
# *** Trial 81: Processing AES_T2100_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      1.04 ms
# Feature Extraction:  184.91 ms
# Prediction:          0.93 ms
#
# *** Trial 82: Processing empty12.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      4.94 ms
# Feature Extraction:  189.54 ms
# Prediction:          0.73 ms
#
# *** Trial 83: Processing AES_T2400.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      2.16 ms
# Feature Extraction:  168.50 ms
# Prediction:          0.90 ms
#
# *** Trial 84: Processing empty11.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      1.85 ms
# Feature Extraction:  168.10 ms
# Prediction:          0.77 ms
#
# *** Trial 85: Processing empty11.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      3.75 ms
# Feature Extraction:  167.24 ms
# Prediction:          0.78 ms
#
# *** Trial 86: Processing empty14.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      2.53 ms
# Feature Extraction:  174.36 ms
# Prediction:          0.75 ms
#
# *** Trial 87: Processing empty19.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      2.39 ms
# Feature Extraction:  161.04 ms
# Prediction:          0.83 ms
#
# *** Trial 88: Processing RS232_T1200.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      2.70 ms
# Feature Extraction:  180.89 ms
# Prediction:          0.35 ms
#
# *** Trial 89: Processing AES_T1300.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      2.38 ms
# Feature Extraction:  168.28 ms
# Prediction:          0.82 ms
#
# *** Trial 90: Processing AES_T1000.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      2.45 ms
# Feature Extraction:  167.18 ms
# Prediction:          0.81 ms
#
# *** Trial 91: Processing RS232_T1200_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.63 ms
# Feature Extraction:  153.49 ms
# Prediction:          0.93 ms
#
# *** Trial 92: Processing RS232_T200_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.60 ms
# Feature Extraction:  178.21 ms
# Prediction:          0.75 ms
#
# *** Trial 93: Processing AES_T1900.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      2.53 ms
# Feature Extraction:  176.39 ms
# Prediction:          1.93 ms
#
# *** Trial 94: Processing AES_T2300_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.24 ms
# Feature Extraction:  161.91 ms
# Prediction:          0.35 ms
#
# *** Trial 95: Processing RS232_T901_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.61 ms
# Feature Extraction:  165.14 ms
# Prediction:          0.66 ms
#
# *** Trial 96: Processing AES_T900.bit... ***
# Actual Class:    Benign (Class 1)
# Predicted Class: Benign (Class 1)
#
# === Latency Summary ===
# Load Bitstream:      2.27 ms
# Feature Extraction:  173.71 ms
# Prediction:          0.81 ms
#
# *** Trial 97: Processing RS232_T300_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.57 ms
# Feature Extraction:  165.16 ms
# Prediction:          4.43 ms
#
# *** Trial 98: Processing RS232_T200_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      3.98 ms
# Feature Extraction:  195.38 ms
# Prediction:          0.33 ms
#
# *** Trial 99: Processing empty19.bit... ***
# Actual Class:    Empty (Class 0)
# Predicted Class: Empty (Class 0)
#
# === Latency Summary ===
# Load Bitstream:      0.70 ms
# Feature Extraction:  170.05 ms
# Prediction:          2.84 ms
#
# *** Trial 100: Processing RS232_T1400_Trojan.bit... ***
# Actual Class:    Malicious (Class 2)
# Predicted Class: Malicious (Class 2)
#
# === Latency Summary ===
# Load Bitstream:      2.54 ms
# Feature Extraction:  156.44 ms
# Prediction:          0.75 ms
#
#
# Average Latency: 0.17 s
#
# Trials Failed: 1 trials

# %%
# --------------------------
# Step 2: List Device and CPU Information
# This step gathers and prints system and processor information from the PYNQ-Z1 to help verify the hardware environment.
# --------------------------
print("=== System Information: ===")
print("System:", platform.system())
print("Node Name:", platform.node())
print("Release:", platform.release())
print("Version:", platform.version())
print("Machine:", platform.machine())
print("Processor:", platform.processor())

print("\n=== CPU Information: ===")
print("CPU Cores:", psutil.cpu_count(logical=False))
print("Logical Processors:", psutil.cpu_count(logical=True))
print("CPU Usage per Core:", psutil.cpu_percent(percpu=True))
print("Total RAM:", psutil.virtual_memory().total / 1024**2, "MB")
# Out:
# === System Information: ===
# System: Darwin
# Node Name: ryebread
# Release: 23.2.0
# Version: Darwin Kernel Version 23.2.0: Wed Nov 15 21:53:34 PST 2023; root:xnu-10002.61.3~2/RELEASE_ARM64_T8103
# Machine: arm64
# Processor: arm
#
# === CPU Information: ===
# CPU Cores: 8
# Logical Processors: 8
# CPU Usage per Core: [88.6, 88.4, 88.0, 87.8, 87.8, 88.4, 87.5, 87.4]
# Total RAM: 8192.0 MB
